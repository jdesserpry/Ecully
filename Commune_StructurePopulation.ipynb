# %%
import pandas as pd

# %% [markdown]
# ## Traitement des fichiers Structure & Population

# %%
structure_population = pd.read_csv('Commune - StructurePopulation/structurepop.csv', sep = ";", decimal=",")

structure_population2009 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2009.xls')
structure_population2010 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2010.xls')
structure_population2011 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2011.xls')
structure_population2012 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2012.xls')
structure_population2013 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2013.xls')
structure_population2014 = pd.read_excel('Commune - StructurePopulation/base-cc-evol-struct-pop-2014.xls')

# %%
structure_population2009 = structure_population2009[structure_population2009.CODGEO=='69081']
structure_population2010 = structure_population2010[structure_population2010.CODGEO=='69081']
structure_population2011 = structure_population2011[structure_population2011.CODGEO=='69081']
structure_population2012 = structure_population2012[structure_population2012.CODGEO=='69081']
structure_population2013 = structure_population2013[structure_population2013.CODGEO=='69081']
structure_population2014 = structure_population2014[structure_population2014.CODGEO=='69081']

# %%
structure_population2009['ANNEE'] = 2009
structure_population2010['ANNEE'] = 2010
structure_population2011['ANNEE'] = 2011
structure_population2012['ANNEE'] = 2012
structure_population2013['ANNEE'] = 2013
structure_population2014['ANNEE'] = 2014

# %%
structure_population['P_POP75P'] = structure_population['P_POP7589'] + structure_population['P_POP90P']
structure_population2011['P_POP75P'] = structure_population2011['P11_POP7589'] + structure_population2011['P11_POP90P']
structure_population2012['P_POP75P'] = structure_population2012['P12_POP7589'] + structure_population2012['P12_POP90P']
structure_population2013['P_POP75P'] = structure_population2013['P13_POP7589'] + structure_population2013['P13_POP90P']
structure_population2014['P_POP75P'] = structure_population2014['P14_POP7589'] + structure_population2014['P14_POP90P']

# %%
structure_population2009[['P_POP01P_IRAN3','P_POP01P_IRAN4','P_POP01P_IRAN5','P_POP01P_IRAN6','P_POP01P_IRAN7']] = ''
structure_population2010[['P_POP01P_IRAN3','P_POP01P_IRAN4','P_POP01P_IRAN5','P_POP01P_IRAN6','P_POP01P_IRAN7']] = ''

# %%
df_structure_population = structure_population[['CODGEO','ANNEE','P_POP',
                                                'P_POP0014','P_POP1529','P_POP3044','P_POP4559','P_POP6074','P_POP75P',
                                                'P_POP01P_IRAN3','P_POP01P_IRAN4','P_POP01P_IRAN5','P_POP01P_IRAN6','P_POP01P_IRAN7',
                                                'C_POP15P_CS1','C_POP15P_CS2', 'C_POP15P_CS3', 'C_POP15P_CS4', 'C_POP15P_CS5'
                                                , 'C_POP15P_CS6', 'C_POP15P_CS7', 'C_POP15P_CS8']]

# %%
df_structure_population2009 = structure_population2009[['CODGEO','ANNEE','P09_POP',
                                                'P09_POP0014','P09_POP1529','P09_POP3044','P09_POP4559','P09_POP6074','P09_POP75P',
                                                'C09_POP15P_CS1','C09_POP15P_CS2', 'C09_POP15P_CS3', 'C09_POP15P_CS4', 'C09_POP15P_CS5'
                                                , 'C09_POP15P_CS6', 'C09_POP15P_CS7', 'C09_POP15P_CS8']]

df_structure_population2009 = (df_structure_population2009
                            .rename(columns={'P09_POP0014':'P_POP0014', 'P09_POP1529':'P_POP1529', 'P09_POP3044':'P_POP3044',
                                             'P09_POP4559':'P_POP4559', 'P09_POP6074':'P_POP6074', 'P09_POP75P':'P_POP75P',
                                             'C09_POP15P_CS1':'C_POP15P_CS1', 'C09_POP15P_CS2':'C_POP15P_CS2', 'C09_POP15P_CS3':'C_POP15P_CS3',
                                             'C09_POP15P_CS4':'C_POP15P_CS4', 'C09_POP15P_CS5':'C_POP15P_CS5', 'C09_POP15P_CS6':'C_POP15P_CS6',
                                             'C09_POP15P_CS7':'C_POP15P_CS7', 'C09_POP15P_CS8':'C_POP15P_CS8', 'P09_POP':'P_POP'
                                                }))

# %%
df_structure_population2010 = structure_population2010[['CODGEO','ANNEE','P10_POP',
                                                'P10_POP0014','P10_POP1529','P10_POP3044','P10_POP4559','P10_POP6074','P10_POP75P',
                                                'C10_POP15P_CS1','C10_POP15P_CS2', 'C10_POP15P_CS3', 'C10_POP15P_CS4', 'C10_POP15P_CS5'
                                                ,'C10_POP15P_CS6', 'C10_POP15P_CS7', 'C10_POP15P_CS8']]

df_structure_population2010 = (df_structure_population2010
                            .rename(columns={'P10_POP0014':'P_POP0014', 'P10_POP1529':'P_POP1529', 'P10_POP3044':'P_POP3044',
                                             'P10_POP4559':'P_POP4559', 'P10_POP6074':'P_POP6074', 'P10_POP75P':'P_POP75P',
                                             'C10_POP15P_CS1':'C_POP15P_CS1', 'C10_POP15P_CS2':'C_POP15P_CS2', 'C10_POP15P_CS3':'C_POP15P_CS3',
                                             'C10_POP15P_CS4':'C_POP15P_CS4', 'C10_POP15P_CS5':'C_POP15P_CS5', 'C10_POP15P_CS6':'C_POP15P_CS6',
                                             'C10_POP15P_CS7':'C_POP15P_CS7', 'C10_POP15P_CS8':'C_POP15P_CS8', 'P10_POP':'P_POP'
                                                }))

# %%
df_structure_population2011 = structure_population2011[['CODGEO','ANNEE','P11_POP',
                                                'P11_POP0014','P11_POP1529','P11_POP3044','P11_POP4559','P11_POP6074','P_POP75P',
                                                'P11_POP01P_IRAN3','P11_POP01P_IRAN4','P11_POP01P_IRAN5','P11_POP01P_IRAN6','P11_POP01P_IRAN7',
                                                'C11_POP15P_CS1','C11_POP15P_CS2', 'C11_POP15P_CS3', 'C11_POP15P_CS4', 'C11_POP15P_CS5'
                                                ,'C11_POP15P_CS6', 'C11_POP15P_CS7', 'C11_POP15P_CS8']]

df_structure_population2011 = (df_structure_population2011
                            .rename(columns={'P11_POP0014':'P_POP0014', 'P11_POP1529':'P_POP1529', 'P11_POP3044':'P_POP3044',
                                             'P11_POP4559':'P_POP4559', 'P11_POP6074':'P_POP6074', 'P11_POP75P':'P_POP75P',
                                             'C11_POP15P_CS1':'C_POP15P_CS1', 'C11_POP15P_CS2':'C_POP15P_CS2', 'C11_POP15P_CS3':'C_POP15P_CS3',
                                             'C11_POP15P_CS4':'C_POP15P_CS4', 'C11_POP15P_CS5':'C_POP15P_CS5', 'C11_POP15P_CS6':'C_POP15P_CS6',
                                             'C11_POP15P_CS7':'C_POP15P_CS7', 'C11_POP15P_CS8':'C_POP15P_CS8',
                                             'P11_POP01P_IRAN3':'P_POP01P_IRAN3','P11_POP01P_IRAN4':'P_POP01P_IRAN4',
                                             'P11_POP01P_IRAN5':'P_POP01P_IRAN5','P11_POP01P_IRAN6':'P_POP01P_IRAN6',
                                             'P11_POP01P_IRAN7':'P_POP01P_IRAN7', 'P11_POP':'P_POP'
                                                }))

# %%
df_structure_population2012 = structure_population2012[['CODGEO','ANNEE','P12_POP',
                                                'P12_POP0014','P12_POP1529','P12_POP3044','P12_POP4559','P12_POP6074','P_POP75P',
                                                'P12_POP01P_IRAN3','P12_POP01P_IRAN4','P12_POP01P_IRAN5','P12_POP01P_IRAN6','P12_POP01P_IRAN7',
                                                'C12_POP15P_CS1','C12_POP15P_CS2', 'C12_POP15P_CS3', 'C12_POP15P_CS4', 'C12_POP15P_CS5'
                                                ,'C12_POP15P_CS6', 'C12_POP15P_CS7', 'C12_POP15P_CS8']]

df_structure_population2012 = (df_structure_population2012
                            .rename(columns={'P12_POP0014':'P_POP0014', 'P12_POP1529':'P_POP1529', 'P12_POP3044':'P_POP3044',
                                             'P12_POP4559':'P_POP4559', 'P12_POP6074':'P_POP6074', 'P12_POP75P':'P_POP75P',
                                             'C12_POP15P_CS1':'C_POP15P_CS1', 'C12_POP15P_CS2':'C_POP15P_CS2', 'C12_POP15P_CS3':'C_POP15P_CS3',
                                             'C12_POP15P_CS4':'C_POP15P_CS4', 'C12_POP15P_CS5':'C_POP15P_CS5', 'C12_POP15P_CS6':'C_POP15P_CS6',
                                             'C12_POP15P_CS7':'C_POP15P_CS7', 'C12_POP15P_CS8':'C_POP15P_CS8',
                                             'P12_POP01P_IRAN3':'P_POP01P_IRAN3','P12_POP01P_IRAN4':'P_POP01P_IRAN4',
                                             'P12_POP01P_IRAN5':'P_POP01P_IRAN5','P12_POP01P_IRAN6':'P_POP01P_IRAN6',
                                             'P12_POP01P_IRAN7':'P_POP01P_IRAN7', 'P12_POP':'P_POP'
                                                }))

# %%
df_structure_population2013 = structure_population2013[['CODGEO','ANNEE','P13_POP',
                                                'P13_POP0014','P13_POP1529','P13_POP3044','P13_POP4559','P13_POP6074','P_POP75P',
                                                'P13_POP01P_IRAN3','P13_POP01P_IRAN4','P13_POP01P_IRAN5','P13_POP01P_IRAN6','P13_POP01P_IRAN7',
                                                'C13_POP15P_CS1','C13_POP15P_CS2', 'C13_POP15P_CS3', 'C13_POP15P_CS4', 'C13_POP15P_CS5'
                                                ,'C13_POP15P_CS6', 'C13_POP15P_CS7', 'C13_POP15P_CS8']]

df_structure_population2013 = (df_structure_population2013
                            .rename(columns={'P13_POP0014':'P_POP0014', 'P13_POP1529':'P_POP1529', 'P13_POP3044':'P_POP3044',
                                             'P13_POP4559':'P_POP4559', 'P13_POP6074':'P_POP6074', 'P13_POP75P':'P_POP75P',
                                             'C13_POP15P_CS1':'C_POP15P_CS1', 'C13_POP15P_CS2':'C_POP15P_CS2', 'C13_POP15P_CS3':'C_POP15P_CS3',
                                             'C13_POP15P_CS4':'C_POP15P_CS4', 'C13_POP15P_CS5':'C_POP15P_CS5', 'C13_POP15P_CS6':'C_POP15P_CS6',
                                             'C13_POP15P_CS7':'C_POP15P_CS7', 'C13_POP15P_CS8':'C_POP15P_CS8',
                                             'P13_POP01P_IRAN3':'P_POP01P_IRAN3','P13_POP01P_IRAN4':'P_POP01P_IRAN4',
                                             'P13_POP01P_IRAN5':'P_POP01P_IRAN5','P13_POP01P_IRAN6':'P_POP01P_IRAN6',
                                             'P13_POP01P_IRAN7':'P_POP01P_IRAN7', 'P13_POP':'P_POP'
                                                }))

# %%
df_structure_population2014 = structure_population2014[['CODGEO','ANNEE','P14_POP',
                                                'P14_POP0014','P14_POP1529','P14_POP3044','P14_POP4559','P14_POP6074','P_POP75P',
                                                'P14_POP01P_IRAN3','P14_POP01P_IRAN4','P14_POP01P_IRAN5','P14_POP01P_IRAN6','P14_POP01P_IRAN7',
                                                'C14_POP15P_CS1','C14_POP15P_CS2', 'C14_POP15P_CS3', 'C14_POP15P_CS4', 'C14_POP15P_CS5'
                                                ,'C14_POP15P_CS6', 'C14_POP15P_CS7', 'C14_POP15P_CS8']]

df_structure_population2014 = (df_structure_population2014
                            .rename(columns={'P14_POP0014':'P_POP0014', 'P14_POP1529':'P_POP1529', 'P14_POP3044':'P_POP3044',
                                             'P14_POP4559':'P_POP4559', 'P14_POP6074':'P_POP6074', 'P14_POP75P':'P_POP75P',
                                             'C14_POP15P_CS1':'C_POP15P_CS1', 'C14_POP15P_CS2':'C_POP15P_CS2', 'C14_POP15P_CS3':'C_POP15P_CS3',
                                             'C14_POP15P_CS4':'C_POP15P_CS4', 'C14_POP15P_CS5':'C_POP15P_CS5', 'C14_POP15P_CS6':'C_POP15P_CS6',
                                             'C14_POP15P_CS7':'C_POP15P_CS7', 'C14_POP15P_CS8':'C_POP15P_CS8',
                                             'P14_POP01P_IRAN3':'P_POP01P_IRAN3','P14_POP01P_IRAN4':'P_POP01P_IRAN4',
                                             'P14_POP01P_IRAN5':'P_POP01P_IRAN5','P14_POP01P_IRAN6':'P_POP01P_IRAN6',
                                             'P14_POP01P_IRAN7':'P_POP01P_IRAN7', 'P14_POP':'P_POP'
                                                }))

# %%
df_structure_population = pd.concat([df_structure_population, df_structure_population2009,df_structure_population2010,df_structure_population2011,df_structure_population2012,df_structure_population2013,df_structure_population2014], axis=0).sort_values('ANNEE').reset_index(drop=True)

# %%
df_structure_population['P_POP01P_IRAN'] = df_structure_population['P_POP01P_IRAN3'] + df_structure_population['P_POP01P_IRAN4'] + df_structure_population['P_POP01P_IRAN5'] + df_structure_population['P_POP01P_IRAN6'] + df_structure_population['P_POP01P_IRAN7']
df_structure_population = df_structure_population.drop(['P_POP01P_IRAN3','P_POP01P_IRAN4','P_POP01P_IRAN5','P_POP01P_IRAN6','P_POP01P_IRAN7'], axis = 1)

# %%
pd.set_option('display.max_columns', None)
df_structure_population
# Out:
#   CODGEO  ANNEE    P_POP    P_POP0014    P_POP1529    P_POP3044    P_POP4559  \
# 0  69081   2009  18071.0  3492.074348  3935.214207  3033.517322  3216.267786
# 1  69081   2010  17998.0  3375.798579  4005.034946  2991.560245  3184.922660
# 2  69081   2011  17854.0  3251.064823  4136.375749  2879.893507  3132.337032
# 3  69081   2012  17742.0  3190.354482  3863.441742  2835.535844  3202.252463
# 4  69081   2013  17787.0  3156.011563  4058.787114  2744.810654  3162.153858
# 5  69081   2014  18028.0  3197.590035  4039.731342  2774.282483  3241.939353
# 6  69081   2015  17947.0  3287.000000  3902.000000  2748.000000  3221.000000
# 7  69081   2016  18097.0  3367.736620  3922.198922  2796.711107  3281.577053
# 8  69081   2017  18517.0  3491.641338  4136.201826  2793.651973  3339.247028
# 9  69081   2018  18587.0  3529.197459  4212.539202  2754.977515  3380.581329
#
#      P_POP6074     P_POP75P  C_POP15P_CS1  C_POP15P_CS2  C_POP15P_CS3  \
# ...

# %%
df_structure_population.to_csv('Data/Commune - structure_population.csv')

# %%
print("Base Structure Population chargée !")
